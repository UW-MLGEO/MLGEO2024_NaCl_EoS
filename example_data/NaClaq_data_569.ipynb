# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
dir0 = '/Users/ulajones/Documents/School/ESS/ESS569F24/MLGeo-dataset/data/WaterProps'
files = os.listdir(dir0)
print(files)
# Out:
# ['water_rho_1bar.csv', 'water_rho_300k.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a figure and a set of subplots

fig, axs = plt.subplots(2, 1, figsize=(12, 10), sharex=False)

file0 = files[0]
df = pd.read_csv(f'{dir0}/{file0}')
axs[0].plot(df['T'], df['Rho'], '-', label=file)
axs[0].set_ylabel('Rho (kg/m3')
axs[0].set_xlabel('T (K)')
axs[0].set_title('Density of water as a function of T at 1 bar')

file1 = files[1]
df = pd.read_csv(f'{dir0}/{file1}')
axs[1].plot(df['P'], df['Rho'], '-', label=file)
axs[1].set_ylabel('Rho (kg/m3)')
axs[1].set_xlabel('P (MPa)')
axs[1].set_title('Density of water as a function of P at 300 K')
# Out:
# Text(0.5, 1.0, 'Density of water as a function of P at 300 K')
