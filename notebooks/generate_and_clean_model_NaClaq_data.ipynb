# %%
# %pip install seafreeze
# %pip install parquet
# %pip install pyarrow
import numpy as np
from seafreeze import seafreeze as sf
import os as os
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
# Out:
# 56770.49s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: seafreeze in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: psutil>=5.9.8 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from seafreeze) (6.0.0)
# Requirement already satisfied: scipy>=1.12 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from seafreeze) (1.14.1)
# Requirement already satisfied: numpy>=1.26.3 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from seafreeze) (1.26.4)
# Requirement already satisfied: h5py>=3.10 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from seafreeze) (3.12.1)
# Requirement already satisfied: hdf5storage>=0.1.19 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from seafreeze) (0.1.19)
# Note: you may need to restart the kernel to use updated packages.
# 56776.45s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: parquet in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: thriftpy2 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from parquet) (0.5.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from thriftpy2->parquet) (3.11)
# Requirement already satisfied: six~=1.15 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from thriftpy2->parquet) (1.16.0)
# Requirement already satisfied: Cython>=3.0.10 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from thriftpy2->parquet) (3.0.11)
# Note: you may need to restart the kernel to use updated packages.
# 56782.32s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting pyarrow
#   Downloading pyarrow-17.0.0-cp311-cp311-macosx_11_0_arm64.whl (27.2 MB)
#      |████████████████████████████████| 27.2 MB 3.1 MB/s eta 0:00:01    |██████████▋                     | 9.1 MB 731 kB/s eta 0:00:25
# Requirement already satisfied: numpy>=1.16.6 in /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages (from pyarrow) (1.26.4)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-17.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Describe the data modalities, data formats
#
# Include a notebook (notebooks/Prepare_AI_Ready_Data.ipynb) that clearly describes:
#
# The final shape of the data (number of samples, features, and target labels).

# %%
dir0 = '/Users/ulajones/Documents/School/ESS/ESS569F24/MLGEO2024_NaCl_EoS/data/raw'

# Define the range of pressure, temperature, and molality
P = np.arange(0.1, 1000.2, 10)
T = np.arange(240, 501, 2)
m = np.arange(0, 7.1, 0.1)

# Define the properties to compute
props = ('G', 'S', 'U', 'H', 'A', 'rho', 'Cp', 'Kt', 'Kp', 'Ks', 'alpha', 'vel', 'mus', 'muw', 'Vm', 'Cpm', 'Cpa', 'Va', 'Vex', 'phi', 'aw', 'gam', 'Gex')
data_dict = {}

for j in props: 
    # Create directories to store the data for each property
    directory_path = os.path.join(dir0, j)
    os.makedirs(directory_path, exist_ok=True)
    dir_clean = os.path.join('/Users/ulajones/Documents/School/ESS/ESS569F24/MLGEO2024_NaCl_EoS/data/clean/', j)
    os.makedirs(dir_clean, exist_ok=True)
    dir_ready = os.path.join('/Users/ulajones/Documents/School/ESS/ESS569F24/MLGEO2024_NaCl_EoS/data/ai_ready/', j)
    os.makedirs(dir_ready, exist_ok=True)
    
    combined_data = []

    # generate individual files for each molality
    for i in m:
        ptm = np.array([P, T, [i]], dtype=object)
        out = sf.getProp(ptm, 'NaClaq')
        i_str = str(i).replace('.', '_')  # Replace decimal point with underscore
        filename = f"props_{j}_{i_str}_molkg.csv"
        
        # extract data and remove unnecessary dimension
        field_data = np.squeeze(getattr(out, j), axis=2)
        
        # Save the combined data to a CSV file
        np.savetxt(os.path.join(directory_path, filename), field_data, delimiter=",", fmt='%s')
                
        # Iterate over temperature and pressure, append all data to a list
        for t_idx, temp in enumerate(T):
            for p_idx, pres in enumerate(P):
                value = field_data[p_idx, t_idx]
                combined_data.append([pres, temp, i, value])
        
    # Drop rows with NaN, inf values
    combined_data = combined_data.replace([np.inf, -np.inf], np.nan, inplace= False)
    combined_data = combined_data.dropna(inplace= False)
    
    # Save combined data to CSV files and parquet tables in the ai ready folder 
    np.savetxt(os.path.join(dir_clean, f"all_props_{j}.csv"), combined_data, delimiter=",", fmt='%s')
    header_list = ['P_Mpa', "T_K", 'm_molkg', f'{j}']
    data_dict[j] = pd.read_csv(os.path.join(dir_clean, f"all_props_{j}.csv"), names=header_list)
    pq.write_table(pa.Table.from_pandas(data_dict[j]), (os.path.join(dir_ready, f'NaCl_{j}.parquet')))

# check the files in the directory
files = os.listdir(directory_path)
print(files)

# read parquet files
for j in props: 
    dir_ready = os.path.join('/Users/ulajones/Documents/School/ESS/ESS569F24/MLGEO2024_NaCl_EoS/data/ai_ready/', j)
    pq.read_table(os.path.join(dir_ready, f'NaCl_{j}.parquet'))
# Out:
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:205: RuntimeWarning: divide by zero encountered in log
#   logVal = 1/R * 1/nu * (tdv.mus - gss) / gPTM[iT].astype(float) - np.log(gPTM[iM].astype(float))
# /opt/anaconda3/envs/mlgeo-dataset/lib/python3.11/site-packages/lbftd/statevars.py:213: RuntimeWarning: invalid value encountered in multiply
#   return R*nu*gPTM[iT]*gPTM[iM]*(np.log(tdv.gam)+(1-tdv.phi))
# ['props_Gex_3_7_molkg.csv', 'props_Gex_6_1000000000000005_molkg.csv', 'props_Gex_3_3000000000000003_molkg.csv', 'props_Gex_0_0_molkg.csv', 'props_Gex_5_6000000000000005_molkg.csv', 'props_Gex_0_30000000000000004_molkg.csv', 'props_Gex_4_2_molkg.csv', 'props_Gex_0_7000000000000001_molkg.csv', 'props_Gex_3_1_molkg.csv', 'props_Gex_4_9_molkg.csv', 'props_Gex_5_0_molkg.csv', 'props_Gex_4_4_molkg.csv', 'props_Gex_4_800000000000001_molkg.csv', 'props_Gex_2_5_molkg.csv', 'props_Gex_6_7_molkg.csv', 'props_Gex_5_7_molkg.csv', 'props_Gex_1_5_molkg.csv', 'props_Gex_0_6000000000000001_molkg.csv', 'props_Gex_3_6_molkg.csv', 'props_Gex_6_0_molkg.csv', 'props_Gex_2_2_molkg.csv', 'props_Gex_1_8_molkg.csv', 'props_Gex_4_3_molkg.csv', 'props_Gex_0_1_molkg.csv', 'props_Gex_6_300000000000001_molkg.csv', 'props_Gex_3_0_molkg.csv', 'props_Gex_2_3000000000000003_molkg.csv', 'props_Gex_1_3_molkg.csv', 'props_Gex_4_5_molkg.csv', 'props_Gex_6_800000000000001_molkg.csv', 'props_Gex_4_6000000000000005_molkg.csv', 'props_Gex_3_5_molkg.csv', 'props_Gex_1_9000000000000001_molkg.csv', 'props_Gex_1_7000000000000002_molkg.csv', 'props_Gex_1_6_molkg.csv', 'props_Gex_5_4_molkg.csv', 'props_Gex_0_2_molkg.csv', 'props_Gex_4_0_molkg.csv', 'props_Gex_2_1_molkg.csv', 'props_Gex_5_9_molkg.csv', 'props_Gex_5_1000000000000005_molkg.csv', 'props_Gex_1_0_molkg.csv', 'props_Gex_5_2_molkg.csv', 'props_Gex_0_9_molkg.csv', 'props_Gex_3_9000000000000004_molkg.csv', 'props_Gex_3_8000000000000003_molkg.csv', 'props_Gex_2_7_molkg.csv', 'props_Gex_6_5_molkg.csv', 'props_Gex_6_6000000000000005_molkg.csv', 'props_Gex_0_4_molkg.csv', 'props_Gex_2_4000000000000004_molkg.csv', 'props_Gex_5_800000000000001_molkg.csv', 'props_Gex_4_1000000000000005_molkg.csv', 'props_Gex_2_8000000000000003_molkg.csv', 'props_Gex_5_5_molkg.csv', 'props_Gex_2_9000000000000004_molkg.csv', 'props_Gex_6_2_molkg.csv', 'props_Gex_3_4000000000000004_molkg.csv', 'props_Gex_2_0_molkg.csv', 'props_Gex_6_9_molkg.csv', 'props_Gex_5_300000000000001_molkg.csv', 'props_Gex_1_1_molkg.csv', 'props_Gex_7_0_molkg.csv', 'props_Gex_0_8_molkg.csv', 'props_Gex_1_2000000000000002_molkg.csv', 'props_Gex_3_2_molkg.csv', 'props_Gex_6_4_molkg.csv', 'props_Gex_1_4000000000000001_molkg.csv', 'props_Gex_2_6_molkg.csv', 'props_Gex_4_7_molkg.csv', 'props_Gex_0_5_molkg.csv']

# %% [markdown]
# I initially generate the SeaFreeze model data as numpy arrays, which I convert to csv files and finally parquet tables. This seems to be the most efficient format for column-oriented data storage + retrieval.
#
# Everything is saved to dedicated folders and organized by thermodynamic variable. Due to the large size of the dataset (1.5 Gb), I am hosting it on Google Drive at this link: https://drive.google.com/drive/folders/1_uFESfnrcsbmZZ5INQRrxB_oK4BcsKiu?usp=drive_link
#
# I chose to save the data as lists of length P*T*m instead of arrays, as this allows me to keep all the data associated with each thermodynamic variable in one file. These can later be reshaped to the original PxT arrays. I filter for inf values, which we might expect around critical points, and NaN values in case I am out of range for any calculations, then deposit the data in the ai_ready folder.
#
# The thermodynamic variables and their units are as follows:
#
# | Quantity  (PT and PTm)      |  Symbol in SeaFreeze  |  Unit (SI)  |
# | --------------- |:---------------------:| :----------:|
# | Gibbs Energy           | `G` | J/kg |
# | Entropy                | `S` | J/K/kg |
# | Internal Energy        | `U` | J/kg |
# | Enthalpy               | `H` | J/kg |
# | Helmholtz free energy  | `A` | J/kg |
# | Density                |`rho`| kg/m^3 |
# | Specific heat capacity at constant pressure|`Cp`| J/kg/K |
# | Specific heat capacity at constant volume|`Cv`| J/kg/K |
# | Isothermal bulk modulus      |`Kt`| MPa |
# | Pressure derivative of the Isothermal bulk modulus|`Kp`| - |
# | Isoentropic bulk modulus     |`Ks`| MPa |
# | Thermal expansivity     |`alpha`| /K |
# | Bulk sound speed     |`vel`| m/s |
# | Solute Chemical Potential           | `mus` | J/mol |
# | Solvent Chemical Potential                | `muw` | J/mol |
# | Partial Molar Volume        | `Vm` | cc/mol |
# | Partial Molar Heat Capacity               | `Cpm` | J/kg/K/mol |
# | Apparent Heat Capacity  | `Cpa` | J/kg/K/mol |
# | Apparent Volume                |`Va`| cc/mol |
# | Excess Volume|`Vex`| cc/mol |
# | Osmotic Coefficient|`phi`| -|
# | Water Activity      |`aw`| - |
# | Activity Coefficient|`gam`| - |
# | Excess Gibbs Energy     |`Gex`| J/kg |
